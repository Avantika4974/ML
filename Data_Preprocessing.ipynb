# %%
#Steps:
#1.import the necessary libraries
#2.import the dataset
#3.Handling null values
#4.Outlier Detection
#5.Seperatle Dependent and independent variables
#6.Encoding
#7.splitting into training and testing set
#8.Feature scaling

# %% [markdown]
# # **1.import the necessary libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **2.import the dataset**

# %%
dataset=pd.read_csv("Churn_Modelling.csv")

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
dataset.head(3)
#top 3 data
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1

# %%
dataset.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
dataset.shape
# Out:
# (10000, 14)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
#if you use dataset.info
dataset.info
# Out:
# <bound method DataFrame.info of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
dataset.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# # **Dependent Variable-Output-'Exited**

# %% [markdown]
# # **Independent Variable-Inputs-All other columns**

# %% [markdown]
# # **# Mean**

# %% [markdown]
# ![Screenshot 2023-09-12 at 10.15.03 AM.png](data:image/png;base64,...)

# %% [markdown]
# # **Standard Deviation**

# %% [markdown]
# ![Screenshot 2023-09-12 at 10.17.03 AM.png](data:image/png;base64,...)

# %% [markdown]
# # **25%- First Quartile**

# %% [markdown]
# # **50%-Median-2nd Quartile**

# %% [markdown]
# # **75%-Third Quartile**

# %% [markdown]
# ![Screenshot 2023-09-12 at 10.18.27 AM.png](data:image/png;base64,...)

# %%
corr=dataset.corr()
corr
# Out:
# <ipython-input-12-f22ca9e9dc13>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=dataset.corr()
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# ...

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
dataset.Exited.value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
dataset.Gender.value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
dataset.Geography.value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %% [markdown]
# # **Outliers**

# %%
sns.boxplot(dataset.Age)
# Out:
# <Axes: >

# %% [markdown]
# # **3.Handling null values**

# %%
dataset.isnull().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
#There is no need to handle null values
#For Example let us assume there are null values in age and gender column

#handling null vlaues in age column(nummerical)----mean/median
#dataset ["Age].fillna(dataset ["Age] .mean (), inplace=True)

#handling null vlaues in Gender column (Categorical)--mode
#dataset ["Gender].fillna(dataset ["Gender ].mode() [e], inplacesTrue)

# %% [markdown]
# # **4. Separating Dependent and Independent Variables**

# %%
x=dataset.iloc[:,3:13]
y=dataset.iloc[:,13:14]

# %%
x.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
y.head()
# Out:
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
x.shape
# Out:
# (10000, 10)

# %%
y.shape
# Out:
# (10000, 1)

# %% [markdown]
# # **5.Encoding**

# %%
#1. nominal encoding---not worried abt arrangement of the data
#a.one hot encoding
#b.one hot encoding ith many categorical variables
#c.mean encoding

#2. ordinal encoding--take care of the order of data
#a.label encoding]
#b. Target guided ordinal encoding

# %% [markdown]
# # **Label encoding on Gender column**

# %%
# apple banana grpes oranges (0-3))
#   0     1      2     3

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
x["Gender"]=le.fit_transform(x["Gender"])

# %%
x["Gender"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    1
# 9996    1
# 9997    0
# 9998    1
# 9999    0
# Name: Gender, Length: 10000, dtype: int64

# %%
x.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France       0   42       2       0.00              1
# 1          608     Spain       0   41       1   83807.86              1
# 2          502    France       0   42       8  159660.80              3
# 3          699    France       0   39       1       0.00              2
# 4          850     Spain       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
x["Gender"].value_counts()
# Out:
# 1    5457
# 0    4543
# Name: Gender, dtype: int64

# %%
x["Gender"].nunique()
# Out:
# 2

# %% [markdown]
# # **One hot encoding on geography column**

# %%
# Geography.      France.   Germany.   Spain
# France           1           0         0
# Germany          0           1         0
# Spain            0           0         1

#here we can ignore one of the columns and encode.

#100 categories 99
#99 columns will be added----curse of dimensionality

# %%
x.shape
# Out:
# (10000, 10)

# %%
geography=pd.get_dummies(x["Geography"],drop_first=True)

# %%
geography
# Out:
#       Germany  Spain
# 0           0      0
# 1           0      1
# 2           0      0
# 3           0      0
# 4           0      1
# ...       ...    ...
# 9995        0      0
# 9996        0      0
# 9997        0      0
# 9998        1      0
# 9999        0      0
#
# [10000 rows x 2 columns]

# %%
x=pd.concat([x,geography],axis=1)

# %%
x.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France       0   42       2       0.00              1
# 1          608     Spain       0   41       1   83807.86              1
# 2          502    France       0   42       8  159660.80              3
# 3          699    France       0   39       1       0.00              2
# 4          850     Spain       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Germany  Spain
# 0          1               1        101348.88        0      0
# 1          0               1        112542.58        0      1
# 2          1               0        113931.57        0      0
# 3          0               0         93826.63        0      0
# 4          1               1         79084.10        0      1

# %%
x.drop(["Geography"],axis=1,inplace=True)

# %%
x.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619       0   42       2       0.00              1          1
# 1          608       0   41       1   83807.86              1          0
# 2          502       0   42       8  159660.80              3          1
# 3          699       0   39       1       0.00              2          0
# 4          850       0   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain
# 0               1        101348.88        0      0
# 1               1        112542.58        0      1
# 2               0        113931.57        0      0
# 3               0         93826.63        0      0
# 4               1         79084.10        0      1

# %%
x.shape
# Out:
# (10000, 11)

# %% [markdown]
# # **7.splitting into training and testing set**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train.shape, x_test.shape, y_train.shape,y_test.shape
# Out:
# ((7000, 11), (3000, 11), (7000, 1), (3000, 1))

# %%
a= [1,2,3,4,5,6]
b= [1,0,1,5,6, 3]

for i in range (5):
  a_train, a_test,b_train,b_test=train_test_split(a,b, test_size=0.3,random_state=0)
  print("with random state",a_train)
# Out:
# with random state [2, 4, 1, 5]
# with random state [2, 4, 1, 5]
# with random state [2, 4, 1, 5]
# with random state [2, 4, 1, 5]
# with random state [2, 4, 1, 5]

# %%
a= [1,2,3,4,5,6]                    # 4 values for training data and 2 for testing data....testing data should not be used for training, userandom_state=0
b= [1,0,1,5,6, 3]

for i in range (5):
  a_train, a_test,b_train,b_test=train_test_split(a,b, test_size=0.3)
  print("without random state",a_train)
# Out:
# without random state [6, 5, 4, 1]
# without random state [4, 3, 6, 2]
# without random state [5, 4, 2, 3]
# without random state [1, 2, 4, 3]
# without random state [4, 2, 5, 1]

# %% [markdown]
# # **8.Feature scaling**

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler ()

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-0.09792126,  0.92295821, -0.55759842, ..., -0.76862426,
#         -0.56987189, -0.5731713 ],
#        [-1.12612023,  0.92295821,  0.01725942, ..., -1.39359887,
#         -0.56987189, -0.5731713 ],
#        [-0.62230274, -1.08347268,  3.5622161 , ..., -1.49739308,
#         -0.56987189, -0.5731713 ],
#        ...,
#        [ 0.89943174,  0.92295821, -0.36597914, ...,  1.41400417,
#         -0.56987189, -0.5731713 ],
#        [-0.62230274, -1.08347268, -0.07855022, ...,  0.84625811,
#         -0.56987189,  1.74467913],
#        [-0.28299708, -1.08347268,  0.87954618, ...,  0.32689267,
#          1.75478035, -0.5731713 ]])
